# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachel-0420/Cross-Entropy-Fast-Transient/blob/real-data/cross_entropy_btw_supernovae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gzip
import numpy as np
import pickle
import math
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# prepend = '/content/drive/MyDrive/'
# input_data_dir = '/content/drive/MyDrive/PrestoColor2/'
# data_dir = '/content/drive/MyDrive/'

# Paths for the Probability Cubes of some transient classes
# SNII and SNIbc are both supernovae and are similar. AGN is very different from the other two

# data1 = input_data_dir + "Datacubes/FullRunTest_1000ObjNo/ProbCube_1229_1815__SNII-Templates.pkl"
# data2 = input_data_dir + "Datacubes/FullRunTest_1000ObjNo/ProbCube_1229_0821__SNIbc-Templates.pkl"
# data3 = input_data_dir + "Datacubes/FullRunTest_1000ObjNo/ProbCube_1229_1819__AGN.pkl"

# %%
# Paths for the Probability Cubes of some transient classes
# SNII and SNIbc are both supernovae and are similar. AGN and KN is very different from the other two

data1 = "/Users/rachelouyang/Desktop/Research/Transient/ProbCube_Data/ProbCube_1229_1815__SNII-Templates.pkl"
data2 = "/Users/rachelouyang/Desktop/Research/Transient/ProbCube_Data/ProbCube_1229_0821__SNIbc-Templates.pkl"
data3 = "/Users/rachelouyang/Desktop/Research/Transient/ProbCube_Data/ProbCube_1229_1819__AGN.pkl"
data4 = "/Users/rachelouyang/Desktop/Research/Transient/ProbCube_Data/ProbCube_0402_0307__KN_B19_full.pkl.gz"

# %%
with open(data1, 'rb') as f1:
    CoordinateDict1 = pickle.load(f1)
    Data1 = pickle.load(f1)

with open(data2, 'rb') as f2:
    CoordinateDict2 = pickle.load(f2)
    Data2 = pickle.load(f2)

with open(data3, 'rb') as f3:
    CoordinateDict3 = pickle.load(f3)
    Data3 = pickle.load(f3)

with gzip.open(data4, 'rb') as f4:
    CoordinateDict4 = pickle.load(f4)
    Data4 = pickle.load(f4)

# %%
#interpretation of the shape of Data

print(len(CoordinateDict2['BandPairs']))
print(len(CoordinateDict2['dT1s']))
print(len(CoordinateDict2['dT2s']))
print(len(CoordinateDict2['dT1s']) * len(CoordinateDict2['dT2s']))
print(len(CoordinateDict2['BinMag']))
print(len(CoordinateDict2['BinColor']))
print(Data1.shape)

print(len(CoordinateDict3['BandPairs']))
print(len(CoordinateDict3['dT1s']))
print(len(CoordinateDict3['dT2s']))
print(len(CoordinateDict3['dT1s']) * len(CoordinateDict3['dT2s']))
print(len(CoordinateDict3['BinMag']))
print(len(CoordinateDict3['BinColor']))
print(Data3.shape)
# Out:
# 28
# 65
# 67
# 4355
# 111
# 39
# (28, 3603, 110, 38)
# 28
# 65
# 67
# 4355
# 111
# 39
# (28, 3603, 110, 38)

# %%
# dictionaries

SNII = {
    "data": np.array(Data1, dtype=float),
    "coordinate_dict": CoordinateDict1,
    "shape": Data1.shape,
    "sum_total": np.sum(Data1),
    "band-pairs": Data1[0],
    "time-pairs": Data1[1],
    "color": Data1[3],
    "mag": Data1[2],
    "band-pairs_axis": 0,
    "time-pairs_axis": 1,
    "color_axis": 3,
    "mag_axis": 2
}

SNIbc = {
    "data": np.array(Data2, dtype=float),
    "coordinate_dict": CoordinateDict2,
    "shape": Data2.shape,
    "sum_total": np.sum(Data2),
    "band-pairs": Data2[0],
    "time-pairs": Data2[1],
    "color": Data2[3],
    "mag": Data2[2],
    "band-pairs_axis": 0,
    "time-pairs_axis": 1,
    "color_axis": 3,
    "mag_axis": 2
}

AGN = {
    "data": np.array(Data3, dtype=float),
    "coordinate_dict": CoordinateDict3,
    "shape": Data3.shape,
    "sum_total": np.sum(Data3),
    "band-pairs": Data3[0],
    "time-pairs": Data3[1],
    "color": Data3[3],
    "mag": Data3[2],
    "band-pairs_axis": 0,
    "time-pairs_axis": 1,
    "color_axis": 3,
    "mag_axis": 2
}

KN = {
    "data": np.array(Data4, dtype=float),
    "coordinate_dict": CoordinateDict4,
    "shape": Data4.shape,
    "sum_total": np.sum(Data4),
    "band-pairs": Data4[0],
    "time-pairs": Data4[1],
    "color": Data4[3],
    "mag": Data4[2],
    "band-pairs_axis": 0,
    "time-pairs_axis": 1,
    "color_axis": 3,
    "mag_axis": 2
}

# %%
datasets = {
    "SNII": SNII,
    "SNIbc": SNIbc,
    "AGN": AGN,
    "KN": KN
}

# %%
print(SNII["coordinate_dict"]['BandPairs'][5])
print(SNII["coordinate_dict"]['BandPairs'][15])
print(SNII["coordinate_dict"]['BandPairs'][27])

print(SNII["coordinate_dict"]['TimePairs'][12])
print(SNII["coordinate_dict"]['TimePairs'][50])
print(SNII["coordinate_dict"]['TimePairs'][100])
# Out:
# gr
# ig
# yz
# [ -480 -1560]
# [-480 1920]
# [-465 1890]

# %% [markdown]
# Data Description Section

# %%
# Sanity Check

fig, axes = plt.subplots(
    2, 4,
    figsize=(18, 6),
    constrained_layout=True,
    sharex="row",
    sharey="row"
)

names = list(datasets.keys())

# Row 1: band-pair marginal (sum over time, color, Δmag)
for j, name in enumerate(names):
    d = datasets[name]
    band_marg = d["data"].sum(axis=(1, 2, 3))  # (band_pair,)
    ax = axes[0, j]
    ax.plot(band_marg)
    ax.set_title(name)
    ax.set_xlabel("Band-pair index")
    if j == 0:
        ax.set_ylabel("Total counts\n(summed over Δt, color, Δmag)")

# Row 2: cadence coverage heatmap (band-pair × time-pair)
ims = []
for j, name in enumerate(names):
    d = datasets[name]
    coverage = d["data"].sum(axis=(2, 3))  # (band_pair, time_pair)
    ax = axes[1, j]
    im = ax.imshow(coverage, origin="lower", aspect="auto")
    ims.append(im)
    ax.set_xlabel("Time-pair index")
    if j == 0:
        ax.set_ylabel("Band-pair index")

# one shared colorbar for the bottom row heatmaps
fig.colorbar(ims[-1], ax=axes[1, :], shrink=0.95, label="Total counts (summed over color, Δmag)")

fig.suptitle("Marginal distributions of the Presto-Color probability hypercube", fontsize=14)
plt.show()


# Sanity Check 2

fig, axes = plt.subplots(
    1, 4,
    figsize=(16, 3),
    sharey=True,
    constrained_layout=True
)

for ax, (name, d) in zip(axes, datasets.items()):
    tm = d["data"].sum(axis=(0, 2, 3))
    ax.plot(tm)
    ax.set_title(name)
    ax.set_xlabel("Time-pair index")

axes[0].set_ylabel("Total counts (summed over band, color, Δmag)")
fig.suptitle("Time-pair coverage of the Presto-Color reference set")

plt.show()

# %% [markdown]
# Method Section

# %%
# Sanity Check

b, t = 5, 12

fig, axes = plt.subplots(1, 4, figsize=(16, 3), constrained_layout=True, sharex=True, sharey=True)

for ax, (name, d) in zip(axes, datasets.items()):
    sl = d["data"][b, t, :, :]

    im = ax.imshow(sl, origin="lower", aspect="auto")
    ax.set_title(name)
    ax.set_xlabel("Δmag bin")
    ax.set_ylabel("Color bin")

fig.colorbar(im, ax=axes, label="(conditional) probability" )
plt.show()

# Sanity Check

for name, transient in datasets.items():
    plt.plot(transient["data"].sum(axis=(0,1,3)), label=name)
plt.semilogy()
plt.ylabel("log of magnitude")
plt.legend()
plt.show()

# %%
def normalize_conditional(data, eps=0.0):
    """
    Normalize the data into p(color, Δmag | band, Δt)
    """
    # data shape: (band, time, color, dmag)
    denom = data.sum(axis=(2, 3), keepdims=True)
    return (data + eps) / (denom + eps)

for name, obj in datasets.items():
    obj["kernel"] = normalize_conditional(obj["data"])

np.allclose(obj["kernel"].sum(axis=(2,3)), 1.0, atol=1e-10)
# Out:
# True

# %%
print(obj["data"].sum(axis=(2,3)))
# Out:
# [[ 142.  156.  155. ...  142.  120.  150.]
#  [ 147.  161.  125. ...  144.  154.  123.]
#  [ 134.  163.  165. ...  158.  171.  143.]
#  ...
#  [3624. 3589. 3537. ... 3728. 3661. 3644.]
#  [3763. 3724. 3753. ... 3699. 3650. 3659.]
#  [3651. 3725. 3633. ... 3668. 3677. 3608.]]

# %%
classes = ["SNII", "SNIbc", "AGN", "KN"]

pair_list_1 = [(5, 12), (5, 50), (5, 100)]
pair_list_2 = [(5, 12), (15, 12), (27, 12)]

example_points = {
    "SNII": [(20, 50), (18, 68)],
    "SNIbc": [(22, 48), (19, 56)],
    "AGN": [(19, 50)],
    "KN": [(22, 48), (19, 50)]
}

# %%
fig, axes = plt.subplots(
    nrows=3,
    ncols=4,
    figsize=(16, 6),
    sharex=True,
    sharey=True,
    constrained_layout=True
)

for row, (b, t) in enumerate(pair_list_1):
    for col, cls in enumerate(classes):
        ax = axes[row, col]

        # extract kernel slice
        K = datasets[cls]["kernel"][b, t]   # shape (Δm, Δc)

        # log scale (safe)
        logK = np.log10(np.clip(K, 1e-16, None))

        im = ax.imshow(
            logK.T,
            origin="lower",
            aspect="auto",
            cmap="viridis"
        )

        # titles
        if row == 0:
            ax.set_title(cls)
        if col == 0:
            ax.set_ylabel(f"Δc bin\n(b={b}, Δt={t})")
        if row == 2:
            ax.set_xlabel("Δm bin")

# single shared colorbar
cbar = fig.colorbar(
    im,
    ax=axes,
    location="right",
    shrink=0.9
)
cbar.set_label(r"$\log_{10}\, p(\Delta m, \Delta c \mid b, \Delta t)$")

fig.suptitle("Cadence-conditioned kernels across transient classes", fontsize=14)

plt.show()

# %%
fig, axes = plt.subplots(
    nrows=3,
    ncols=4,
    figsize=(16, 6),
    sharex=True,
    sharey=True,
    constrained_layout=True
)

for row, (b, t) in enumerate(pair_list_2):
    for col, cls in enumerate(classes):
        ax = axes[row, col]

        # extract kernel slice
        K = datasets[cls]["kernel"][b, t]   # shape (Δm, Δc)

        # # log scale (safe)
        logK = np.log10(np.clip(K, 1e-16, None))

        im = ax.imshow(
            logK.T,
            origin="lower",
            aspect="auto",
            cmap="inferno"
        )

        # titles
        if row == 0:
            ax.set_title(cls)
        if col == 0:
            ax.set_ylabel(f"Δc bin\n(b={b}, Δt={t})")
        if row == 2:
            ax.set_xlabel("Δm bin")

# single shared colorbar
cbar = fig.colorbar(
    im,
    ax=axes,
    location="right",
    shrink=0.9
)
cbar.set_label(r"$\log_{10}\, p(\Delta m, \Delta c \mid b, \Delta t)$")

fig.suptitle("Cadence-conditioned kernels across transient classes", fontsize=14)

plt.show()

# %%
# Choice of Time Pairs

tp = SNII["coordinate_dict"]["TimePairs"]
index = list()
dt1 = None

# dT1 = -465
idx = list()
dt1 = -465
target1 = np.array([dt1, -1500])
target2 = np.array([dt1, -480])
target3 = np.array([dt1, 0])
target4 = np.array([dt1, 480])
target5 = np.array([dt1, 1500])
idx.append(np.where((tp == target1).all(axis=1))[0])
idx.append(np.where((tp == target2).all(axis=1))[0])
idx.append(np.where((tp == target3).all(axis=1))[0])
idx.append(np.where((tp == target4).all(axis=1))[0])
idx.append(np.where((tp == target5).all(axis=1))[0])
index += idx
print(idx)

# dT1 = -210
idx = list()
dt1 = -210
target1 = np.array([dt1, -1500])
target2 = np.array([dt1, -480])
target3 = np.array([dt1, 0])
target4 = np.array([dt1, 480])
target5 = np.array([dt1, 1500])
idx.append(np.where((tp == target1).all(axis=1))[0])
idx.append(np.where((tp == target2).all(axis=1))[0])
idx.append(np.where((tp == target3).all(axis=1))[0])
idx.append(np.where((tp == target4).all(axis=1))[0])
idx.append(np.where((tp == target5).all(axis=1))[0])
index += idx
print(idx)

# dT1 = 0
idx = list()
dt1 = 0
target1 = np.array([dt1, -1500])
target2 = np.array([dt1, -480])
target3 = np.array([dt1, 0])
target4 = np.array([dt1, 480])
target5 = np.array([dt1, 1500])
idx.append(np.where((tp == target1).all(axis=1))[0])
idx.append(np.where((tp == target2).all(axis=1))[0])
idx.append(np.where((tp == target3).all(axis=1))[0])
idx.append(np.where((tp == target4).all(axis=1))[0])
idx.append(np.where((tp == target5).all(axis=1))[0])
index += idx
print(idx)

# dT1 = 210
idx = list()
dt1 = 210
target1 = np.array([dt1, -1500])
target2 = np.array([dt1, -480])
target3 = np.array([dt1, 0])
target4 = np.array([dt1, 480])
target5 = np.array([dt1, 1500])
idx.append(np.where((tp == target1).all(axis=1))[0])
idx.append(np.where((tp == target2).all(axis=1))[0])
idx.append(np.where((tp == target3).all(axis=1))[0])
idx.append(np.where((tp == target4).all(axis=1))[0])
idx.append(np.where((tp == target5).all(axis=1))[0])
index += idx
print(idx)

# dT1 = 465
idx = list()
dt1 = 465
target1 = np.array([dt1, -1500])
target2 = np.array([dt1, -480])
target3 = np.array([dt1, 0])
target4 = np.array([dt1, 480])
target5 = np.array([dt1, 1500])
idx.append(np.where((tp == target1).all(axis=1))[0])
idx.append(np.where((tp == target2).all(axis=1))[0])
idx.append(np.where((tp == target3).all(axis=1))[0])
idx.append(np.where((tp == target4).all(axis=1))[0])
idx.append(np.where((tp == target5).all(axis=1))[0])
index += idx
print(idx)
# Out:
# [array([65]), array([], dtype=int64), array([68]), array([84]), array([87])]
# [array([935]), array([938]), array([941]), array([957]), array([960])]
# [array([1782]), array([1785]), array([1801]), array([1817]), array([1820])]
# [array([2642]), array([2645]), array([2661]), array([2664]), array([2667])]
# [array([3515]), array([3518]), array([3534]), array([], dtype=int64), array([3537])]

# %%
classes = ["SNII", "SNIbc", "AGN", "KN"]
pair_list = [(5, int(i.item())) 
             for i in index 
             if i.size == 1]
print(np.shape((pair_list)))
# Out:
# (23, 2)

# %%
nrows = 3
chunk_size = nrows

n_figs = math.ceil(len(pair_list) / chunk_size)

for fig_idx in range(n_figs):

    start = fig_idx * chunk_size
    end = start + chunk_size
    chunk = pair_list[start:end]

    fig, axes = plt.subplots(
        nrows=3,
        ncols=4,
        figsize=(16, 6),
        sharex=True,
        sharey=True,
        constrained_layout=True
    )

    for row, (b, t) in enumerate(chunk):
        for col, cls in enumerate(classes):
            ax = axes[row, col]

            # extract kernel slice
            K = datasets[cls]["kernel"][b, t]

            logK = np.log10(np.clip(K, 1e-16, None))

            im = ax.imshow(
                logK.T,
                origin="lower",
                aspect="auto",
                cmap="viridis"
            )

            # titles
            if row == 0:
                ax.set_title(cls)
            if col == 0:
                ax.set_ylabel(f"Δc bin\n(b={b}, Δt={t})")
            if row == 2:
                ax.set_xlabel("Δm bin")

    # hide unused rows if last chunk < 3
    for empty_row in range(len(chunk), 3):
        for col in range(3):
            axes[empty_row, col].axis("off")

    # single shared colorbar
    cbar = fig.colorbar(
        im,
        ax=axes,
        location="right",
        shrink=0.9
    )
    cbar.set_label(r"$\log_{10}\, p(\Delta m, \Delta c \mid b, \Delta t)$")

    fig.suptitle(
        "Cadence-conditioned kernels across transient classes",
        fontsize=14
    )

    plt.show()

# %%
print(SNII["coordinate_dict"]['TimePairs'][68])
print(SNII["coordinate_dict"]['TimePairs'][936])
print(SNII["coordinate_dict"]['TimePairs'][3518])

pair_time_final = [(5, 68), (5, 936), (5, 3518)]
# Out:
# [-465    0]
# [ -210 -1470]
# [ 465 -480]

# %%
fig, axes = plt.subplots(
    nrows=3,
    ncols=4,
    figsize=(16, 6),
    sharex=True,
    sharey=True,
    constrained_layout=True
)

for row, (b, t) in enumerate(pair_time_final):
    for col, cls in enumerate(classes):
        ax = axes[row, col]

        # extract kernel slice
        K = datasets[cls]["kernel"][b, t]   # shape (Δm, Δc)

        # log scale (safe)
        logK = np.log10(np.clip(K, 1e-16, None))

        im = ax.imshow(
            logK.T,
            origin="lower",
            aspect="auto",
            cmap="inferno"
        )

        # titles
        if row == 0:
            ax.set_title(cls)
        if col == 0:
            ax.set_ylabel(f"Δc bin\n(b={b}, Δt={t})")
        if row == 2:
            ax.set_xlabel("Δm bin")

# single shared colorbar
cbar = fig.colorbar(
    im,
    ax=axes,
    location="right",
    shrink=0.9
)
cbar.set_label(r"$\log_{10}\, p(\Delta m, \Delta c \mid b, \Delta t)$")

fig.suptitle("Cadence-conditioned kernels across transient classes", fontsize=14)

plt.show()

# %% [markdown]
# Normalization

# %%
def normalize_for_4D_data(data_set):
    data_set["data_norm"] = 1 / data_set["sum_total"] * data_set["data"]
    return None

for name, obj in datasets.items():
    normalize_for_4D_data(obj)
    print((np.sum(obj["data_norm"])))
    print(name, math.isclose(np.sum(obj["data_norm"]), 1.0))
# Out:
# 1.0000000000000064
# SNII True
# 1.0000000000000056
# SNIbc True
# 1.0000000000000044
# AGN True
# 0.9999999999999989
# KN True

# %% [markdown]
# Cross Entropy

# %%
def cross_entropy(p, q, eps=1e-16):
    return -np.sum(p * np.log(np.clip(q, eps, None)))

def cross_entropy_2(p, q, eps=1e-16): # To check that the small positive ground is valid
    return -np.sum((p+eps) * np.log(q+eps))

dists = {
    "SNII": SNII["data_norm"],
    "SNIbc": SNIbc["data_norm"],
    "AGN": AGN["data_norm"],
    "KN": KN["data_norm"],
}

labels = list(dists)
H = np.array([[cross_entropy(dists[i], dists[j])
               for j in labels]
              for i in labels])

H2 = H = np.array([[cross_entropy_2(dists[i], dists[j])
               for j in labels]
              for i in labels])

# %%
from matplotlib.colors import LinearSegmentedColormap

def create_sequential_cmap(base_color, n_colors=256, name='custom',
                           dark_level=0.2, light_level=1.0):
    """
    Create a sequential colormap with adjustable dark/light limits.

    Parameters:
    - base_color: str or tuple, base color
    - n_colors: int, number of colors in colormap
    - dark_level: float, how dark the darkest shade becomes (0=black, 1=original)
    - light_level: float, how light the lightest shade becomes (1=white, >1=brighter)
    """
    from matplotlib.colors import to_rgb
    rgb = np.array(to_rgb(base_color))

    # Create color array
    colors = []
    for i in range(n_colors):
        # Linear interpolation between dark and light
        t = i / (n_colors - 1)

        # Interpolate between dark and light shades
        dark_shade = rgb * dark_level
        light_shade = np.ones(3) * light_level
        color = dark_shade * (1 - t) + light_shade * t

        # Clip values to valid range [0, 1]
        color = np.clip(color, 0, 1)
        colors.append(color)

    return LinearSegmentedColormap.from_list(name, colors)

purple = '#9b59b6'
cmap_dark = create_sequential_cmap(purple, dark_level=0.1, light_level=0.9, name='purple_dark')
cmap_medium = create_sequential_cmap(purple, dark_level=0.4, light_level=1.0, name='purple_medium')
cmap_light = create_sequential_cmap(purple, dark_level=0.7, light_level=1.0, name='purple_light')

# %%
# For H by Method 1

fig, ax = plt.subplots(figsize=(4, 4))

im = ax.imshow(H, cmap=cmap_medium)

ax.set_xticks(range(len(labels)))
ax.set_yticks(range(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

ax.set_xlabel("Reference")
# ax.set_ylabel("Data distribution p")
ax.set_title("Cross-entropy H(p, q)")

# annotate values
for i in range(len(labels)):
    for j in range(len(labels)):
        ax.text(j, i, f"{H[i,j]:.2f}",
                ha="center", va="center", 
                color='w' if H[i, j]<25 else 'k'
                # color="white",
                # bbox=dict(
                #     boxstyle="round,pad=0.20",
                #     fc="black",
                #     ec="none",
                #     alpha=0.40
                #     )
                )

# fig.colorbar(im, ax=ax, label="Cross entropy")
plt.tight_layout()
plt.show()

# For H by Method 2

fig2, ax2 = plt.subplots(figsize=(4, 4))

im2 = ax2.imshow(H2, cmap=cmap_medium)

ax2.set_xticks(range(len(labels)))
ax2.set_yticks(range(len(labels)))
ax2.set_xticklabels(labels)
ax2.set_yticklabels(labels)

ax2.set_xlabel("Reference")
# ax2.set_ylabel("Data distribution p")
ax2.set_title("Cross-entropy H(p, q)")

# annotate values
for i in range(len(labels)):
    for j in range(len(labels)):
        ax2.text(j, i, f"{H2[i,j]:.2f}",
                ha="center", va="center", 
                color='w' if H2[i, j]<25 else 'k'
                # color="white",bbox=dict(
                # boxstyle="round,pad=0.20",
                # fc="black",
                # ec="none",
                # alpha=0.40)
                )

# fig2.colorbar(im2, ax=ax2, label="Cross entropy")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(4, 4))

im = ax.imshow(H-H2, cmap="viridis")

ax.set_xticks(range(len(labels)))
ax.set_yticks(range(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

ax.set_xlabel("Scoring distribution q")
ax.set_ylabel("Data distribution p")
ax.set_title("Cross-entropy Sanity Check")

# annotate values
for i in range(len(labels)):
    for j in range(len(labels)):
        ax.text(j, i, f"{H[i,j]-H2[i,j]:.2f}",
                ha="center", va="center", color="white")

fig.colorbar(im, ax=ax, label="Cross entropy difference")
plt.tight_layout()
plt.show()
